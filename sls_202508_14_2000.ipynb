# %% [markdown]
# <a href="https://colab.research.google.com/github/toledotorrespatricio/hjb-nn-mmcc/blob/main/sls_202508_14_2000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================================
# VERSIÓN MEJORADA: Con normalización de costos + checkpointing por paso
# Evita cargar 2000 redes en RAM/VRAM. Crea, entrena, guarda y libera por paso.
# ============================================================================
import os, gc, datetime, numpy as np, tensorflow as tf
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# ---------------------------------------------
# Configuración GPU
# ---------------------------------------------
gpus = tf.config.list_physical_devices('GPU')
for g in gpus:
    try:
        tf.config.experimental.set_memory_growth(g, True)
    except Exception as e:
        print("⚠️ No se pudo setear memory growth:", e)

DEVICE = '/GPU:0' if gpus else '/CPU:0'
print("🔧  Usando dispositivo:", DEVICE)

# ---------------------------------------------
# Logging y checkpoints
# ---------------------------------------------
log_dir = "logs/slscheme_improved/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
writer = tf.summary.create_file_writer(log_dir)

CKPT_DIR = "ckpts_slscheme_improved"
os.makedirs(CKPT_DIR, exist_ok=True)

def ctrl_path(n): return os.path.join(CKPT_DIR, f"ctrl_{n}.weights.h5")
def val_path(n):  return os.path.join(CKPT_DIR, f"val_{n}.weights.h5")

with tf.device(DEVICE):
    # -----------------------------------------------------------------------
    # 1) PARÁMETROS DEL SISTEMA
    # -----------------------------------------------------------------------
    C1, C2, C3 = 1_000.0, 5_000.0, 1e-3

    A_mat = tf.constant([[1., 0., .5],
                         [0., 1., .5]], dtype=tf.float32)
    A_pinv = tf.linalg.pinv(A_mat)

    K_mat = tf.constant([[ 2/3, -1/3, -1/3],
                         [-1/3,  2/3, -1/3],
                         [-1/3, -1/3,  2/3]], dtype=tf.float32)

    state_dim, control_dim = 7, 3
    x_min, x_max = 0., 1_000.
    y_min, y_max = -15., 15.
    u_min, u_max = -1., 1.
    λ_w, λ_x, λ_z, λ_u = 0.85, 0.05, 0.05, 0.05
    w_ref_0 = np.array([15.0, 5.0])  # w_ref en t=0
    A_np = np.array([[1., 0., 0.5], [0., 1., 0.5]])
    y_inicial = np.linalg.pinv(A_np) @ w_ref_0

    # -----------------------------------------------------------------------
    # PARÁMETROS DE NORMALIZACIÓN DE COSTOS
    # -----------------------------------------------------------------------
    # Error w: Ay - w_ref
    e_w_min = tf.constant([-20., -10.], dtype=tf.float32)
    e_w_max = tf.constant([20., 10.], dtype=tf.float32)

    # Error x: x - x_ref
    e_x_min = tf.constant([-880., -880., -880.], dtype=tf.float32)
    e_x_max = tf.constant([120., 120., 120.], dtype=tf.float32)

    # Error z: (I - A^T A)y  (usamos A_pinv A)
    e_z_min = tf.constant([-15., -15., -15.], dtype=tf.float32)
    e_z_max = tf.constant([15., 15., 15.], dtype=tf.float32)

    # Error u: A^T d(t) - K diag{x} u
    e_u_min = tf.constant([-1000., -1000., -1000.], dtype=tf.float32)
    e_u_max = tf.constant([1000., 1000., 1000.], dtype=tf.float32)

    # Calcular e_DC y e_peak para cada error
    e_w_DC = (e_w_max + e_w_min) / 2.0
    e_w_peak = (e_w_max - e_w_min) / 2.0

    e_x_DC = (e_x_max + e_x_min) / 2.0
    e_x_peak = (e_x_max - e_x_min) / 2.0

    e_z_DC = (e_z_max + e_z_min) / 2.0
    e_z_peak = (e_z_max - e_z_min) / 2.0

    e_u_DC = (e_u_max + e_u_min) / 2.0
    e_u_peak = (e_u_max - e_u_min) / 2.0

    # Calcular E_k,N^2 para normalización
    E_w_N_sq = tf.reduce_sum(e_w_DC**2) + 0.5 * tf.reduce_sum(e_w_peak**2)
    E_x_N_sq = tf.reduce_sum(e_x_DC**2) + 0.5 * tf.reduce_sum(e_x_peak**2)
    E_z_N_sq = tf.reduce_sum(e_z_DC**2) + 0.5 * tf.reduce_sum(e_z_peak**2)
    E_u_N_sq = tf.reduce_sum(e_u_DC**2) + 0.5 * tf.reduce_sum(e_u_peak**2)

    # -----------------------------------------------------------------------
    # NORMALIZACIÓN (CRÍTICO!)
    # -----------------------------------------------------------------------
    x_scale = (x_max - x_min) / 2.0
    x_offset = (x_max + x_min) / 2.0
    y_scale = (y_max - y_min) / 2.0
    y_offset = (y_max + y_min) / 2.0

    @tf.function
    def normalize_state(state):
        """Normaliza estado a [-1, 1]"""
        x, y, z = state[:, :3], state[:, 3:6], state[:, 6:7]
        x_norm = (x - x_offset) / x_scale
        y_norm = (y - y_offset) / y_scale
        z_norm = z / 10.0  # Normalizar costo acumulado
        return tf.concat([x_norm, y_norm, z_norm], axis=1)

    @tf.function
    def denormalize_state(state_norm):
        """Desnormaliza estado"""
        x_norm, y_norm, z_norm = state_norm[:, :3], state_norm[:, 3:6], state_norm[:, 6:7]
        x = x_norm * x_scale + x_offset
        y = y_norm * y_scale + y_offset
        z = z_norm * 10.0
        return tf.concat([x, y, z], axis=1)

    # -----------------------------------------------------------------------
    # 2) DISCRETIZACIÓN TEMPORAL
    # -----------------------------------------------------------------------
    T, N, p = 0.8, 2000, 20
    dt = T / N

    # -----------------------------------------------------------------------
    # 3) REFERENCIAS
    # -----------------------------------------------------------------------
    @tf.function
    def w_ref(t):
        val = 5.0 * tf.cos(5.0 * np.pi * t)
        return tf.stack([5.0, val], axis=0)[None, :]

    x_ref = tf.constant([[880., 880., 880.]], tf.float32)

    @tf.function
    def d_ref(t):
        val = 300. * tf.cos(5. * np.pi * t)
        return tf.stack([500.0, val], axis=0)[None, :]

    # -----------------------------------------------------------------------
    # 4) DINÁMICA AUMENTADA CON CLIPPING
    # -----------------------------------------------------------------------
    @tf.function
    def f_aug(state, u, t):
        x, y = state[:, :3], state[:, 3:6]

        # Limitar valores para evitar explosión
        x = tf.clip_by_value(x, x_min, x_max)
        y = tf.clip_by_value(y, y_min, y_max)
        u = tf.clip_by_value(u, u_min, u_max)

        dx = C1 * y * u

        dvec = tf.repeat(d_ref(t), tf.shape(state)[0], axis=0)
        ATd = tf.matmul(dvec, A_mat)

        Kxu = tf.matmul(x * u, K_mat, transpose_b=True)
        dy = C2 * (-C3 * y + ATd - Kxu)

        # Calcular errores
        wvec = tf.repeat(w_ref(t), tf.shape(state)[0], axis=0)
        e_w = tf.matmul(y, A_mat, transpose_b=True) - wvec

        x_ref_repeated = tf.repeat(x_ref, tf.shape(state)[0], axis=0)
        e_x = x - x_ref_repeated

        zmat = tf.eye(3) - tf.matmul(A_pinv, A_mat)
        e_z = tf.matmul(y, zmat, transpose_b=True)

        e_u = ATd - Kxu

        # Costos normalizados
        Jw = tf.reduce_sum(e_w**2, axis=1, keepdims=True) / E_w_N_sq
        Jx = tf.reduce_sum(e_x**2, axis=1, keepdims=True) / E_x_N_sq
        Jz = tf.reduce_sum(e_z**2, axis=1, keepdims=True) / E_z_N_sq
        Ju = tf.reduce_sum(e_u, axis=1, keepdims=True) / E_u_N_sq

        Lval = λ_w*Jw + λ_x*Jx + λ_z*Jz + λ_u*Ju

        # Limitar gradientes
        dx = tf.clip_by_value(dx, -1000., 1000.)
        dy = tf.clip_by_value(dy, -100., 100.)
        Lval = tf.clip_by_value(Lval, 0., 10.)

        return tf.concat([dx, dy, Lval], 1)

    # -----------------------------------------------------------------------
    # 5) FUNCIONES AUXILIARES
    # -----------------------------------------------------------------------
    @tf.function
    def g_obstacle(state):
        x, y = state[:, :3], state[:, 3:6]
        vx = tf.maximum(x_min - x, x - x_max)
        vy = tf.maximum(y_min - y, y - y_max)
        violation = tf.maximum(tf.reduce_max(vx, 1), tf.reduce_max(vy, 1))
        return tf.clip_by_value(violation, -10., 10.)  # Penalización

    @tf.function
    def phi_terminal(state):
        return tf.clip_by_value(state[:, 6], 0., 100.)

    def sample_states(batch):
        """Muestreo más inteligente"""
        if tf.random.uniform([]) < 0.8:
            x = tf.random.normal([batch, 3], mean=500., stddev=200.)
            y = tf.random.normal([batch, 3], mean=0., stddev=5.)
        else:
            x = tf.random.uniform([batch, 3], x_min, x_max)
            y = tf.random.uniform([batch, 3], y_min, y_max)

        x = tf.clip_by_value(x, x_min, x_max)
        y = tf.clip_by_value(y, y_min, y_max)
        z = tf.zeros([batch, 1])
        return tf.concat([x, y, z], 1)

    # -----------------------------------------------------------------------
    # 6) OPERADORES F_a y G_a
    # -----------------------------------------------------------------------
    @tf.function
    def F_a(state, u, t0):
        """Propaga estado - IMPORTANTE: state en escala original"""
        s, t = state, t0
        dt_p = dt / p
        for _ in tf.range(p):
            s += dt_p * f_aug(s, u, t)
            s = tf.concat([tf.clip_by_value(s[:, :3], x_min, x_max),
                           tf.clip_by_value(s[:, 3:6], y_min, y_max),
                           s[:, 6:]], 1)
            t += dt_p
        return s

    @tf.function
    def G_a(state, u, t0):
        """Calcula violaciones - IMPORTANTE: state en escala original"""
        s, t = state, t0
        m = tf.zeros([tf.shape(state)[0]])  # Inicializar en 0
        dt_p = dt / p
        for _ in tf.range(p):
            s += dt_p * f_aug(s, u, t)
            s = tf.concat([tf.clip_by_value(s[:, :3], x_min, x_max),
                           tf.clip_by_value(s[:, 3:6], y_min, y_max),
                           s[:, 6:]], 1)
            m = tf.maximum(m, g_obstacle(s))
            t += dt_p
        return m

    # -----------------------------------------------------------------------
    # 7) REDES NEURONALES
    # -----------------------------------------------------------------------
    def create_control_net():
        """Red con regularización y normalización"""
        return tf.keras.Sequential([
            tf.keras.layers.Input((state_dim,)),
            tf.keras.layers.Lambda(normalize_state),
            tf.keras.layers.Dense(24, activation='relu',
                                  kernel_initializer='glorot_uniform',
                                  kernel_regularizer=tf.keras.regularizers.l2(1e-4)),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(16, activation='relu',
                                  kernel_regularizer=tf.keras.regularizers.l2(1e-4)),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(control_dim, activation='tanh')
        ])

    def create_value_net():
        """Red de valor con normalización"""
        return tf.keras.Sequential([
            tf.keras.layers.Input((state_dim,)),
            tf.keras.layers.Lambda(normalize_state),
            tf.keras.layers.Dense(24, activation='relu',
                                  kernel_initializer='glorot_uniform',
                                  kernel_regularizer=tf.keras.regularizers.l2(1e-4)),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(24, activation='relu',
                                  kernel_regularizer=tf.keras.regularizers.l2(1e-4)),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(1)
        ])

    # -----------------------------------------------------------------------
    # 8) ENTRENAMIENTO (checkpointing por paso, sin acumular 2000 redes)
    # -----------------------------------------------------------------------
    epochs_ctrl = 30
    epochs_val  = 30
    bs = 128
    patience = 5
    min_delta = 1e-3

    print("🚀 Iniciando entrenamiento con checkpointing por paso...")

    for n in reversed(range(N)):
        t0 = tf.constant(float(n)*dt, tf.float32)
        print(f"\n=== Paso {n}/{N-1} ===")

        # (Re)crear optimizadores por seguridad al limpiar sesión
        opt_u = tf.keras.optimizers.Adam(5e-4, clipnorm=1.0)
        opt_V = tf.keras.optimizers.Adam(5e-4, clipnorm=1.0)

        # 1) Crear redes del paso n
        ctrl_n = create_control_net()
        val_n  = create_value_net()
        # forward dummy para "build"
        _ = ctrl_n(tf.zeros((1, state_dim)))
        _ = val_n(tf.zeros((1, state_dim)))

        # 2) Cargar V_{n+1} (congelada) si existe, para el bootstrap
        v_next = None
        if n + 1 < N and os.path.exists(val_path(n+1)):
            v_next = create_value_net()
            _ = v_next(tf.zeros((1, state_dim)))
            v_next.load_weights(val_path(n+1))
            v_next.trainable = False

        # 3) Entrenar control en paso n
        best_loss, no_improve = float('inf'), 0
        for e in range(1, epochs_ctrl+1):
            S = sample_states(bs)
            with tf.GradientTape() as g:
                u = ctrl_n(S, training=True)
                u = tf.clip_by_value(u, u_min, u_max)

                if v_next is None:  # n == N-1
                    Tt = tf.maximum(G_a(S, u, t0), phi_terminal(F_a(S, u, t0)))
                else:
                    next_state = F_a(S, u, t0)
                    next_value = tf.squeeze(v_next(next_state, training=False))
                    Tt = tf.maximum(G_a(S, u, t0), next_value)

                Tt = tf.clip_by_value(Tt, 0., 100.)
                reg = 1e-6 * tf.add_n([tf.nn.l2_loss(w) for w in ctrl_n.trainable_weights])
                loss = tf.reduce_mean(Tt) + reg

            grads = g.gradient(loss, ctrl_n.trainable_variables)
            if all(g is not None for g in grads):
                opt_u.apply_gradients(zip(grads, ctrl_n.trainable_variables))

            if float(loss) < best_loss - min_delta:
                best_loss, no_improve = float(loss), 0
            else:
                no_improve += 1
            if no_improve >= patience:
                print(f"  Early stopping control en época {e}")
                break
            if e % 10 == 0:
                print(f"  ctrl epoch {e} loss {float(loss):.6f}")

        # 4) Entrenar valor en paso n
        best_loss_v, no_improve_v = float('inf'), 0
        for e in range(1, epochs_val+1):
            S = sample_states(bs)
            u = ctrl_n(S, training=False)
            u = tf.clip_by_value(u, u_min, u_max)

            if v_next is None:  # n == N-1
                Tt = tf.maximum(G_a(S, u, t0), phi_terminal(F_a(S, u, t0)))
            else:
                next_state = F_a(S, u, t0)
                next_value = tf.squeeze(v_next(next_state, training=False))
                Tt = tf.maximum(G_a(S, u, t0), next_value)

            with tf.GradientTape() as gV:
                pred = tf.squeeze(val_n(S, training=True))
                T_clipped = tf.clip_by_value(tf.stop_gradient(Tt), 0., 100.)
                lossV = tf.reduce_mean((pred - T_clipped)**2)

            grads_V = gV.gradient(lossV, val_n.trainable_variables)
            if all(g is not None for g in grads_V):
                opt_V.apply_gradients(zip(grads_V, val_n.trainable_variables))

            if float(lossV) < best_loss_v - min_delta:
                best_loss_v, no_improve_v = float(lossV), 0
            else:
                no_improve_v += 1
            if no_improve_v >= patience:
                print(f"  Early stopping valor en época {e}")
                break
            if e % 10 == 0:
                print(f"  val epoch {e} loss {float(lossV):.6f}")

        # 5) Guardar pesos del paso n y liberar memoria
        ctrl_n.save_weights(ctrl_path(n))
        val_n.save_weights(val_path(n))

        del ctrl_n, val_n, v_next, opt_u, opt_V
        gc.collect()
        tf.keras.backend.clear_session()

    # -----------------------------------------------------------------------
    # 9) SIMULACIÓN (carga on-demand de cada red de control)
    # -----------------------------------------------------------------------
    def create_and_load_ctrl(n):
        m = create_control_net()
        _ = m(tf.zeros((1, state_dim)))
        m.load_weights(ctrl_path(n))
        return m

    def control_trajectory_SL(x0):
        s = tf.convert_to_tensor(x0[None, :], tf.float32)
        traj, u_seq = [x0.copy()], []
        t = tf.constant(0., tf.float32)

        for n in range(N):
            ctrl_n = create_and_load_ctrl(n)
            u = ctrl_n(s, training=False)
            u = tf.clip_by_value(u, u_min, u_max)
            u_seq.append(u.numpy()[0])

            s = F_a(s, u, t)
            traj.append(s.numpy()[0])
            t += dt

            del ctrl_n
            gc.collect()
            tf.keras.backend.clear_session()

        return np.array(traj), np.array(u_seq)

# -----------------------------------------------------------------------------
# Ejemplo de uso post-entrenamiento (descomentar para simular)
# -----------------------------------------------------------------------------
# x0 = np.array([500., 500., 500., 0., 0., 0., 0.], dtype=np.float32)
# traj, u_seq = control_trajectory_SL(x0)
# print("Trayectoria shape:", traj.shape, "Control shape:", u_seq.shape)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# === Paso 867/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.413395
#   val epoch 20 loss 0.994120
#   val epoch 30 loss 0.680237
#
# === Paso 866/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 3.956528
#   Early stopping valor en época 17
#
# === Paso 865/1999 ===
#   ctrl epoch 10 loss 0.069976
#   Early stopping control en época 11
#   val epoch 10 loss 1.219966
#   val epoch 20 loss 0.976236
#   val epoch 30 loss 0.806781
#
# === Paso 864/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 0.972209
#   val epoch 20 loss 0.718442
#   Early stopping valor en época 28
#
# === Paso 863/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.204678
#   Early stopping valor en época 15
#
# === Paso 862/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.530450
#   val epoch 20 loss 1.584858
#   Early stopping valor en época 23
#
# === Paso 861/1999 ===
#   Early stopping control en época 7
#   Early stopping valor en época 8
#
# === Paso 860/1999 ===
#   Early stopping control en época 6
#   Early stopping valor en época 7
#
# === Paso 859/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.562048
#   val epoch 20 loss 0.995632
#   val epoch 30 loss 0.779503
#
# === Paso 858/1999 ===
#   ctrl epoch 10 loss 0.164104
#   Early stopping control en época 11
#   val epoch 10 loss 1.549659
#   val epoch 20 loss 1.082605
#   val epoch 30 loss 0.863749
#
# === Paso 857/1999 ===
#   Early stopping control en época 8
#   Early stopping valor en época 10
#
# === Paso 856/1999 ===
#   ctrl epoch 10 loss 0.160030
#   Early stopping control en época 12
#   val epoch 10 loss 0.958452
#   val epoch 20 loss 0.677378
#   val epoch 30 loss 0.568763
#
# === Paso 855/1999 ===
#   ctrl epoch 10 loss 0.136695
#   Early stopping control en época 15
#   val epoch 10 loss 1.276445
#   val epoch 20 loss 0.571144
#   Early stopping valor en época 24
#
# === Paso 854/1999 ===
#   ctrl epoch 10 loss 0.159161
#   Early stopping control en época 13
#   val epoch 10 loss 1.023586
#   Early stopping valor en época 19
#
# === Paso 853/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 2.148933
#   val epoch 20 loss 1.077754
#   val epoch 30 loss 0.765972
#
# === Paso 852/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.184089
#   val epoch 20 loss 0.713544
#   val epoch 30 loss 0.485101
#
# === Paso 851/1999 ===
#   ctrl epoch 10 loss 0.240303
#   Early stopping control en época 11
#   val epoch 10 loss 1.289281
#   Early stopping valor en época 19
#
# === Paso 850/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.132564
#   Early stopping valor en época 18
#
# === Paso 849/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.184311
#   val epoch 20 loss 0.778008
#   val epoch 30 loss 0.553097
#
# === Paso 848/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.343000
#   val epoch 20 loss 0.678288
#   val epoch 30 loss 0.595097
#
# === Paso 847/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.261984
#   val epoch 20 loss 0.762969
#   val epoch 30 loss 0.540245
#
# === Paso 846/1999 ===
#   ctrl epoch 10 loss 0.012098
#   Early stopping control en época 15
#   val epoch 10 loss 0.922803
#   val epoch 20 loss 0.766160
#   Early stopping valor en época 23
#
# === Paso 845/1999 ===
#   ctrl epoch 10 loss 0.022558
#   Early stopping control en época 12
#   val epoch 10 loss 1.546240
#   val epoch 20 loss 1.221276
#   val epoch 30 loss 0.770181
#
# === Paso 844/1999 ===
#   ctrl epoch 10 loss 0.026081
#   Early stopping control en época 11
#   val epoch 10 loss 2.419514
#   val epoch 20 loss 2.090082
#   Early stopping valor en época 26
#
# === Paso 843/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.359973
#   val epoch 20 loss 0.818457
#   Early stopping valor en época 23
#
# === Paso 842/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.247407
#   val epoch 20 loss 0.821119
#   val epoch 30 loss 0.434837
#
# === Paso 841/1999 ===
#   ctrl epoch 10 loss 0.061583
#   Early stopping control en época 13
#   val epoch 10 loss 0.926333
#   Early stopping valor en época 15
#
# === Paso 840/1999 ===
#   ctrl epoch 10 loss 0.016491
#   Early stopping control en época 15
#   val epoch 10 loss 1.995967
#   val epoch 20 loss 0.818572
#   Early stopping valor en época 25
#
# === Paso 839/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 2.164246
#   Early stopping valor en época 13
#
# === Paso 838/1999 ===
#   ctrl epoch 10 loss 0.016253
#   Early stopping control en época 11
#   val epoch 10 loss 2.415780
#   Early stopping valor en época 14
#
# === Paso 837/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.231089
#   Early stopping valor en época 11
#
# === Paso 836/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.241862
#   val epoch 20 loss 0.742808
#   Early stopping valor en época 30
#
# === Paso 835/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.008809
#   val epoch 20 loss 0.587640
#   val epoch 30 loss 0.424667
#
# === Paso 834/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 0.692532
#   Early stopping valor en época 16
#
# === Paso 833/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.975627
#   val epoch 20 loss 0.628566
#   val epoch 30 loss 0.566193
#
# === Paso 832/1999 ===
#   ctrl epoch 10 loss 0.062187
#   Early stopping control en época 13
#   val epoch 10 loss 1.928379
#   Early stopping valor en época 12
#
# === Paso 831/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.319236
#   Early stopping valor en época 11
#
# === Paso 830/1999 ===
#   ctrl epoch 10 loss 0.038615
#   Early stopping control en época 19
#   val epoch 10 loss 1.601326
#   val epoch 20 loss 1.067158
#   Early stopping valor en época 29
#
# === Paso 829/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.704082
#   val epoch 20 loss 1.019148
#   val epoch 30 loss 0.841055
#
# === Paso 828/1999 ===
#   ctrl epoch 10 loss 0.135637
#   Early stopping control en época 12
#   val epoch 10 loss 1.805487
#   val epoch 20 loss 1.552972
#   Early stopping valor en época 27
#
# === Paso 827/1999 ===
#   ctrl epoch 10 loss 0.078493
#   Early stopping control en época 11
#   val epoch 10 loss 1.349912
#   val epoch 20 loss 0.784179
#   val epoch 30 loss 0.544667
#
# === Paso 826/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.188228
#   val epoch 20 loss 0.808500
#   Early stopping valor en época 23
#
# === Paso 825/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.480020
#   val epoch 20 loss 1.145293
#   val epoch 30 loss 0.646165
#
# === Paso 824/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.223089
#   val epoch 20 loss 1.103536
#   val epoch 30 loss 0.872346
#
# === Paso 823/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.743452
#   val epoch 20 loss 0.494449
#   Early stopping valor en época 21
#
# === Paso 822/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.310703
#   val epoch 20 loss 1.162911
#   val epoch 30 loss 0.749988
#
# === Paso 821/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 2.217781
#   val epoch 20 loss 1.577433
#   Early stopping valor en época 28
#
# === Paso 820/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.573060
#   val epoch 20 loss 1.153513
#   val epoch 30 loss 0.897713
#
# === Paso 819/1999 ===
#   Early stopping control en época 8
#   Early stopping valor en época 8
#
# === Paso 818/1999 ===
#   Early stopping control en época 10
#   Early stopping valor en época 8
#
# === Paso 817/1999 ===
#   ctrl epoch 10 loss 0.114170
#   Early stopping control en época 15
#   val epoch 10 loss 1.468642
#   val epoch 20 loss 1.195702
#   val epoch 30 loss 0.807011
#
# === Paso 816/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.079151
#   val epoch 20 loss 0.796701
#   Early stopping valor en época 21
#
# === Paso 815/1999 ===
#   ctrl epoch 10 loss 0.036065
#   Early stopping control en época 11
#   val epoch 10 loss 2.070991
#   Early stopping valor en época 13
#
# === Paso 814/1999 ===
#   ctrl epoch 10 loss 0.212773
#   Early stopping control en época 13
#   val epoch 10 loss 2.056481
#   val epoch 20 loss 1.144003
#   val epoch 30 loss 0.675697
#
# === Paso 813/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.492576
#   val epoch 20 loss 1.296954
#   val epoch 30 loss 0.786103
#
# === Paso 812/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.928571
#   val epoch 20 loss 0.636217
#   val epoch 30 loss 0.457529
#
# === Paso 811/1999 ===
#   ctrl epoch 10 loss 0.032547
#   Early stopping control en época 11
#   val epoch 10 loss 2.224448
#   val epoch 20 loss 1.404165
#   val epoch 30 loss 0.709945
#
# === Paso 810/1999 ===
#   ctrl epoch 10 loss 0.144921
#   Early stopping control en época 12
#   val epoch 10 loss 1.486372
#   Early stopping valor en época 18
#
# === Paso 809/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 3.105251
#   Early stopping valor en época 11
#
# === Paso 808/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.603737
#   Early stopping valor en época 15
#
# === Paso 807/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.491807
#   val epoch 20 loss 1.307473
#   val epoch 30 loss 0.780418
#
# === Paso 806/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.884570
#   val epoch 20 loss 1.266648
#   val epoch 30 loss 0.712767
#
# === Paso 805/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.295382
#   Early stopping valor en época 14
#
# === Paso 804/1999 ===
#   ctrl epoch 10 loss 0.130279
#   Early stopping control en época 11
#   val epoch 10 loss 2.045116
#   val epoch 20 loss 1.329403
#   val epoch 30 loss 0.758521
#
# === Paso 803/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.304141
#   val epoch 20 loss 1.041895
#   val epoch 30 loss 0.667412
#
# === Paso 802/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.684460
#   val epoch 20 loss 1.047927
#   Early stopping valor en época 30
#
# === Paso 801/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.511224
#   val epoch 20 loss 0.857709
#   val epoch 30 loss 0.519913
#
# === Paso 800/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.064384
#   val epoch 20 loss 0.752610
#   Early stopping valor en época 27
#
# === Paso 799/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 0.987154
#   val epoch 20 loss 0.718495
#   Early stopping valor en época 26
#
# === Paso 798/1999 ===
#   ctrl epoch 10 loss 0.075682
#   Early stopping control en época 14
#   val epoch 10 loss 1.649644
#   Early stopping valor en época 14
#
# === Paso 797/1999 ===
#   ctrl epoch 10 loss 0.091581
#   Early stopping control en época 15
#   val epoch 10 loss 2.137485
#   val epoch 20 loss 1.641848
#   Early stopping valor en época 26
#
# === Paso 796/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 0.827432
#   val epoch 20 loss 0.557514
#   val epoch 30 loss 0.344994
#
# === Paso 795/1999 ===
#   ctrl epoch 10 loss 0.167988
#   Early stopping control en época 11
#   val epoch 10 loss 0.829254
#   Early stopping valor en época 11
#
# === Paso 794/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.362034
#   Early stopping valor en época 18
#
# === Paso 793/1999 ===
#   ctrl epoch 10 loss 0.057160
#   Early stopping control en época 11
#   val epoch 10 loss 1.775127
#   Early stopping valor en época 13
#
# === Paso 792/1999 ===
#   ctrl epoch 10 loss 0.037495
#   Early stopping control en época 16
#   val epoch 10 loss 0.658546
#   val epoch 20 loss 0.546439
#   Early stopping valor en época 27
#
# === Paso 791/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.638637
#   Early stopping valor en época 19
#
# === Paso 790/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.759669
#   val epoch 20 loss 1.167148
#   val epoch 30 loss 0.805404
#
# === Paso 789/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.207357
#   Early stopping valor en época 18
#
# === Paso 788/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.800068
#   Early stopping valor en época 16
#
# === Paso 787/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.123914
#   val epoch 20 loss 0.826274
#   val epoch 30 loss 0.424028
#
# === Paso 786/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.401057
#   Early stopping valor en época 11
#
# === Paso 785/1999 ===
#   Early stopping control en época 9
#   Early stopping valor en época 6
#
# === Paso 784/1999 ===
#   Early stopping control en época 7
#   Early stopping valor en época 8
#
# === Paso 783/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 0.854576
#   val epoch 20 loss 0.410420
#   val epoch 30 loss 0.326203
#
# === Paso 782/1999 ===
#   ctrl epoch 10 loss 0.039070
#   Early stopping control en época 11
#   val epoch 10 loss 1.525707
#   val epoch 20 loss 0.943706
#   val epoch 30 loss 0.657138
#
# === Paso 781/1999 ===
#   Early stopping control en época 8
#   Early stopping valor en época 6
#
# === Paso 780/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.426381
#   val epoch 20 loss 0.847972
#   val epoch 30 loss 0.577712
#
# === Paso 779/1999 ===
#   ctrl epoch 10 loss 0.080879
#   Early stopping control en época 13
#   val epoch 10 loss 1.512265
#   val epoch 20 loss 1.188019
#   Early stopping valor en época 23
#
# === Paso 778/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.958015
#   val epoch 20 loss 1.050273
#   Early stopping valor en época 29
#
# === Paso 777/1999 ===
#   ctrl epoch 10 loss 0.095553
#   Early stopping control en época 12
#   val epoch 10 loss 1.943854
#   val epoch 20 loss 1.151748
#   val epoch 30 loss 0.792569
#
# === Paso 776/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.913456
#   Early stopping valor en época 13
#
# === Paso 775/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.016190
#   val epoch 20 loss 0.566140
#   Early stopping valor en época 21
#
# === Paso 774/1999 ===
#   ctrl epoch 10 loss 0.130020
#   Early stopping control en época 11
#   val epoch 10 loss 1.606187
#   val epoch 20 loss 1.114340
#   Early stopping valor en época 21
#
# === Paso 773/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.376049
#   val epoch 20 loss 0.980040
#   val epoch 30 loss 0.627482
#
# === Paso 772/1999 ===
#   Early stopping control en época 7
#   Early stopping valor en época 6
#
# === Paso 771/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 0.809757
#   val epoch 20 loss 0.741287
#   Early stopping valor en época 22
#
# === Paso 770/1999 ===
#   Early stopping control en época 6
#   Early stopping valor en época 10
#
# === Paso 769/1999 ===
#   ctrl epoch 10 loss 0.044965
#   Early stopping control en época 12
#   val epoch 10 loss 1.746836
#   val epoch 20 loss 1.052896
#   val epoch 30 loss 0.927459
#
# === Paso 768/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 0.980201
#   val epoch 20 loss 0.814359
#   Early stopping valor en época 21
#
# === Paso 767/1999 ===
#   ctrl epoch 10 loss 0.105425
#   Early stopping control en época 14
#   val epoch 10 loss 1.048702
#   Early stopping valor en época 11
#
# === Paso 766/1999 ===
#   ctrl epoch 10 loss 0.092186
#   Early stopping control en época 12
#   val epoch 10 loss 1.336652
#   Early stopping valor en época 14
#
# === Paso 765/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.064715
#   val epoch 20 loss 0.646842
#   Early stopping valor en época 26
#
# === Paso 764/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.823524
#   val epoch 20 loss 1.697186
#   val epoch 30 loss 1.035298
#
# === Paso 763/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.611126
#   Early stopping valor en época 12
#
# === Paso 762/1999 ===
#   ctrl epoch 10 loss 0.062077
#   Early stopping control en época 12
#   val epoch 10 loss 1.639714
#   Early stopping valor en época 11
#
# === Paso 761/1999 ===
#   ctrl epoch 10 loss 0.031615
#   Early stopping control en época 11
#   Early stopping valor en época 8
#
# === Paso 760/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.385272
#   val epoch 20 loss 0.809708
#   Early stopping valor en época 22
#
# === Paso 759/1999 ===
#   ctrl epoch 10 loss 0.165393
#   Early stopping control en época 11
#   val epoch 10 loss 1.488225
#   Early stopping valor en época 15
#
# === Paso 758/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.972031
#   Early stopping valor en época 14
#
# === Paso 757/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 2.614211
#   val epoch 20 loss 1.765987
#   Early stopping valor en época 27
#
# === Paso 756/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.381897
#   Early stopping valor en época 20
#
# === Paso 755/1999 ===
#   ctrl epoch 10 loss 0.046022
#   Early stopping control en época 11
#   Early stopping valor en época 7
#
# === Paso 754/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 2.264415
#   val epoch 20 loss 1.622101
#   Early stopping valor en época 27
#
# === Paso 753/1999 ===
#   ctrl epoch 10 loss 0.006932
#   Early stopping control en época 15
#   Early stopping valor en época 9
#
# === Paso 752/1999 ===
#   ctrl epoch 10 loss 0.013763
#   Early stopping control en época 15
#   Early stopping valor en época 6
#
# === Paso 751/1999 ===
#   Early stopping control en época 8
#   Early stopping valor en época 7
#
# === Paso 750/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 0.734566
#   val epoch 20 loss 0.566634
#   val epoch 30 loss 0.473086
#
# === Paso 749/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.002661
#   Early stopping valor en época 20
#
# === Paso 748/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.484746
#   val epoch 20 loss 1.147532
#   Early stopping valor en época 29
#
# === Paso 747/1999 ===
#   ctrl epoch 10 loss 0.108509
#   Early stopping control en época 11
#   val epoch 10 loss 1.273738
#   val epoch 20 loss 0.820966
#   val epoch 30 loss 0.604070
#
# === Paso 746/1999 ===
#   ctrl epoch 10 loss 0.134493
#   Early stopping control en época 16
#   Early stopping valor en época 6
#
# === Paso 745/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.455638
#   Early stopping valor en época 17
#
# === Paso 744/1999 ===
#   Early stopping control en época 7
#   Early stopping valor en época 7
#
# === Paso 743/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.093900
#   val epoch 20 loss 0.547229
#   val epoch 30 loss 0.446397
#
# === Paso 742/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.551381
#   val epoch 20 loss 0.902008
#   Early stopping valor en época 25
#
# === Paso 741/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.919954
#   val epoch 20 loss 1.261423
#   val epoch 30 loss 1.104685
#
# === Paso 740/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 0.940491
#   val epoch 20 loss 0.779854
#   val epoch 30 loss 0.530284
#
# === Paso 739/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 0.613451
#   val epoch 20 loss 0.462821
#   Early stopping valor en época 26
#
# === Paso 738/1999 ===
#   ctrl epoch 10 loss 0.071218
#   Early stopping control en época 11
#   val epoch 10 loss 1.414024
#   Early stopping valor en época 12
#
# === Paso 737/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 0.757297
#   val epoch 20 loss 0.529113
#   Early stopping valor en época 23
#
# === Paso 736/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 2.246618
#   val epoch 20 loss 1.326880
#   val epoch 30 loss 0.875146
#
# === Paso 735/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 2.898134
#   Early stopping valor en época 20
#
# === Paso 734/1999 ===
#   ctrl epoch 10 loss 0.168912
#   Early stopping control en época 15
#   val epoch 10 loss 1.313491
#   val epoch 20 loss 0.728414
#   val epoch 30 loss 0.560540
#
# === Paso 733/1999 ===
#   Early stopping control en época 6
#   Early stopping valor en época 9
#
# === Paso 732/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 0.921763
#   val epoch 20 loss 0.477369
#   val epoch 30 loss 0.398881
#
# === Paso 731/1999 ===
#   ctrl epoch 10 loss 0.120418
#   Early stopping control en época 16
#   val epoch 10 loss 1.786750
#   val epoch 20 loss 1.106538
#   val epoch 30 loss 0.768785
#
# === Paso 730/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.346103
#   val epoch 20 loss 1.120323
#   Early stopping valor en época 21
#
# === Paso 729/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.506658
#   val epoch 20 loss 0.650556
#   val epoch 30 loss 0.614050
#
# === Paso 728/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 0.555517
#   val epoch 20 loss 0.368095
#   Early stopping valor en época 30
#
# === Paso 727/1999 ===
#   Early stopping control en época 6
#   Early stopping valor en época 10
#
# === Paso 726/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.319625
#   val epoch 20 loss 0.733671
#   val epoch 30 loss 0.704909
#
# === Paso 725/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.651207
#   val epoch 20 loss 1.212482
#   val epoch 30 loss 0.699766
#
# === Paso 724/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.478992
#   val epoch 20 loss 1.408160
#   Early stopping valor en época 22
#
# === Paso 723/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.355521
#   Early stopping valor en época 13
#
# === Paso 722/1999 ===
#   ctrl epoch 10 loss 0.026644
#   Early stopping control en época 12
#   val epoch 10 loss 1.890934
#   val epoch 20 loss 1.371026
#   val epoch 30 loss 0.705847
#
# === Paso 721/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.441749
#   Early stopping valor en época 12
#
# === Paso 720/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.142685
#   val epoch 20 loss 0.782811
#   val epoch 30 loss 0.579053
#
# === Paso 719/1999 ===
#   Early stopping control en época 7
#   Early stopping valor en época 6
#
# === Paso 718/1999 ===
#   Early stopping control en época 8
#   Early stopping valor en época 6
#
# === Paso 717/1999 ===
#   ctrl epoch 10 loss 0.088553
#   Early stopping control en época 11
#   val epoch 10 loss 1.222509
#   val epoch 20 loss 0.797790
#   val epoch 30 loss 0.635082
#
# === Paso 716/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.735324
#   val epoch 20 loss 1.222818
#   val epoch 30 loss 0.710294
#
# === Paso 715/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 2.338422
#   Early stopping valor en época 11
#
# === Paso 714/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 2.348100
#   val epoch 20 loss 1.549018
#   val epoch 30 loss 1.220122
#
# === Paso 713/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 0.723329
#   val epoch 20 loss 0.523384
#   Early stopping valor en época 23
#
# === Paso 712/1999 ===
#   ctrl epoch 10 loss 0.104564
#   Early stopping control en época 16
#   val epoch 10 loss 1.327249
#   val epoch 20 loss 0.992275
#   val epoch 30 loss 0.655925
#
# === Paso 711/1999 ===
#   Early stopping control en época 7
#   Early stopping valor en época 8
#
# === Paso 710/1999 ===
#   ctrl epoch 10 loss 0.029917
#   Early stopping control en época 11
#   val epoch 10 loss 0.785870
#   val epoch 20 loss 0.696545
#   val epoch 30 loss 0.398378
#
# === Paso 709/1999 ===
#   Early stopping control en época 6
#   Early stopping valor en época 6
#
# === Paso 708/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 0.960535
#   Early stopping valor en época 17
#
# === Paso 707/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.563647
#   Early stopping valor en época 18
#
# === Paso 706/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 0.967739
#   val epoch 20 loss 0.598764
#   Early stopping valor en época 26
#
# === Paso 705/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.861849
#   val epoch 20 loss 1.264718
#   val epoch 30 loss 0.794186
#
# === Paso 704/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.299916
#   val epoch 20 loss 1.063179
#   val epoch 30 loss 0.722789
#
# === Paso 703/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.665808
#   val epoch 20 loss 1.276517
#   val epoch 30 loss 0.664528
#
# === Paso 702/1999 ===
#   ctrl epoch 10 loss 0.015962
#   Early stopping control en época 11
#   val epoch 10 loss 1.858143
#   val epoch 20 loss 1.387229
#   Early stopping valor en época 26
#
# === Paso 701/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 0.809084
#   val epoch 20 loss 0.502747
#   val epoch 30 loss 0.411961
#
# === Paso 700/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.086450
#   val epoch 20 loss 0.834851
#   Early stopping valor en época 28
#
# === Paso 699/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.320632
#   Early stopping valor en época 16
#
# === Paso 698/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.229248
#   val epoch 20 loss 0.803887
#   val epoch 30 loss 0.582534
#
# === Paso 697/1999 ===
#   ctrl epoch 10 loss 0.090812
#   Early stopping control en época 12
#   val epoch 10 loss 1.220958
#   Early stopping valor en época 13
#
# === Paso 696/1999 ===
#   ctrl epoch 10 loss 0.126584
#   Early stopping control en época 12
#   val epoch 10 loss 2.164091
#   val epoch 20 loss 1.221788
#   val epoch 30 loss 1.031993
#
# === Paso 695/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 0.832267
#   val epoch 20 loss 0.489500
#   val epoch 30 loss 0.363160
#
# === Paso 694/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 2.338392
#   val epoch 20 loss 1.166668
#   val epoch 30 loss 0.936037
#
# === Paso 693/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.154454
#   val epoch 20 loss 0.663785
#   val epoch 30 loss 0.575874
#
# === Paso 692/1999 ===
#   ctrl epoch 10 loss 0.022099
#   Early stopping control en época 13
#   val epoch 10 loss 1.904420
#   Early stopping valor en época 15
#
# === Paso 691/1999 ===
#   ctrl epoch 10 loss 0.081275
#   Early stopping control en época 12
#   val epoch 10 loss 1.317091
#   val epoch 20 loss 0.846887
#   val epoch 30 loss 0.576458
#
# === Paso 690/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 2.025802
#   Early stopping valor en época 20
#
# === Paso 689/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 2.303836
#   val epoch 20 loss 1.651779
#   val epoch 30 loss 0.927717
#
# === Paso 688/1999 ===
#   ctrl epoch 10 loss 0.270824
#   Early stopping control en época 14
#   val epoch 10 loss 1.980095
#   Early stopping valor en época 15
#
# === Paso 687/1999 ===
#   Early stopping control en época 8
#   Early stopping valor en época 7
#
# === Paso 686/1999 ===
#   ctrl epoch 10 loss 0.022814
#   Early stopping control en época 18
#   val epoch 10 loss 1.037697
#   val epoch 20 loss 0.552489
#   val epoch 30 loss 0.331665
#
# === Paso 685/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.581655
#   val epoch 20 loss 1.074290
#   val epoch 30 loss 0.872331
#
# === Paso 684/1999 ===
#   ctrl epoch 10 loss 0.227211
#   Early stopping control en época 11
#   val epoch 10 loss 1.953167
#   Early stopping valor en época 20
#
# === Paso 683/1999 ===
#   ctrl epoch 10 loss 0.058709
#   Early stopping control en época 18
#   val epoch 10 loss 0.611548
#   Early stopping valor en época 12
#
# === Paso 682/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 2.013844
#   Early stopping valor en época 11
#
# === Paso 681/1999 ===
#   ctrl epoch 10 loss 0.175334
#   Early stopping control en época 16
#   val epoch 10 loss 0.932739
#   val epoch 20 loss 0.623378
#   val epoch 30 loss 0.460697
#
# === Paso 680/1999 ===
#   Early stopping control en época 6
#   Early stopping valor en época 8
#
# === Paso 679/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.671813
#   val epoch 20 loss 1.282360
#   val epoch 30 loss 0.941750
#
# === Paso 678/1999 ===
#   Early stopping control en época 8
#   Early stopping valor en época 10
#
# === Paso 677/1999 ===
#   Early stopping control en época 6
#   Early stopping valor en época 6
#
# === Paso 676/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.540832
#   Early stopping valor en época 14
#
# === Paso 675/1999 ===
#   Early stopping control en época 9
#   Early stopping valor en época 10
#
# === Paso 674/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.319898
#   val epoch 20 loss 1.250355
#   Early stopping valor en época 27
#
# === Paso 673/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.382972
#   val epoch 20 loss 0.813851
#   val epoch 30 loss 0.740687
#
# === Paso 672/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.443430
#   val epoch 20 loss 0.644909
#   val epoch 30 loss 0.600499
#
# === Paso 671/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 2.776610
#   val epoch 20 loss 2.312951
#   val epoch 30 loss 1.567611
#
# === Paso 670/1999 ===
#   ctrl epoch 10 loss 0.013197
#   Early stopping control en época 11
#   val epoch 10 loss 1.568458
#   val epoch 20 loss 1.050840
#   val epoch 30 loss 0.665582
#
# === Paso 669/1999 ===
#   Early stopping control en época 7
#   Early stopping valor en época 6
#
# === Paso 668/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.861581
#   val epoch 20 loss 1.138946
#   val epoch 30 loss 0.851109
#
# === Paso 667/1999 ===
#   ctrl epoch 10 loss 0.043089
#   Early stopping control en época 11
#   val epoch 10 loss 0.882835
#   Early stopping valor en época 12
#
# === Paso 666/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 0.688290
#   Early stopping valor en época 18
#
# === Paso 665/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 0.593501
#   Early stopping valor en época 14
#
# === Paso 664/1999 ===
#   Early stopping control en época 10
#   Early stopping valor en época 8
#
# === Paso 663/1999 ===
#   ctrl epoch 10 loss 0.027029
#   Early stopping control en época 12
#   val epoch 10 loss 2.523407
#   val epoch 20 loss 1.458971
#   val epoch 30 loss 1.065395
#
# === Paso 662/1999 ===
#   ctrl epoch 10 loss 0.116164
#   Early stopping control en época 13
#   Early stopping valor en época 9
#
# === Paso 661/1999 ===
#   ctrl epoch 10 loss 0.020055
#   Early stopping control en época 13
#   Early stopping valor en época 6
#
# === Paso 660/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.679471
#   Early stopping valor en época 20
#
# === Paso 659/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 0.909006
#   val epoch 20 loss 0.622031
#   val epoch 30 loss 0.289001
#
# === Paso 658/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.000275
#   val epoch 20 loss 0.621112
#   Early stopping valor en época 21
#
# === Paso 657/1999 ===
#   ctrl epoch 10 loss 0.043363
#   Early stopping control en época 11
#   val epoch 10 loss 1.047397
#   val epoch 20 loss 0.828003
#   Early stopping valor en época 24
#
# === Paso 656/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.325957
#   Early stopping valor en época 11
#
# === Paso 655/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 0.658671
#   val epoch 20 loss 0.395236
#   Early stopping valor en época 21
#
# === Paso 654/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.618536
#   val epoch 20 loss 1.168034
#   val epoch 30 loss 0.805758
#
# === Paso 653/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 2.436365
#   val epoch 20 loss 1.709716
#   val epoch 30 loss 0.917559
#
# === Paso 652/1999 ===
#   ctrl epoch 10 loss 0.082324
#   Early stopping control en época 11
#   val epoch 10 loss 1.390112
#   val epoch 20 loss 0.819189
#   Early stopping valor en época 25
#
# === Paso 651/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.261606
#   Early stopping valor en época 12
#
# === Paso 650/1999 ===
#   ctrl epoch 10 loss 0.028607
#   Early stopping control en época 14
#   val epoch 10 loss 0.899485
#   val epoch 20 loss 0.611047
#   Early stopping valor en época 30
#
# === Paso 649/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 0.940337
#   Early stopping valor en época 20
#
# === Paso 648/1999 ===
#   Early stopping control en época 7
#   Early stopping valor en época 6
#
# === Paso 647/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.242436
#   val epoch 20 loss 1.064741
#   val epoch 30 loss 0.646231
#
# === Paso 646/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.669350
#   val epoch 20 loss 0.365777
#   val epoch 30 loss 0.308361
#
# === Paso 645/1999 ===
#   Early stopping control en época 10
#   Early stopping valor en época 10
#
# === Paso 644/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.793231
#   Early stopping valor en época 17
#
# === Paso 643/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 2.064126
#   val epoch 20 loss 1.407238
#   Early stopping valor en época 22
#
# === Paso 642/1999 ===
#   ctrl epoch 10 loss 0.119359
#   Early stopping control en época 13
#   val epoch 10 loss 1.357638
#   Early stopping valor en época 20
#
# === Paso 641/1999 ===
#   ctrl epoch 10 loss 0.079012
#   Early stopping control en época 11
#   Early stopping valor en época 10
#
# === Paso 640/1999 ===
#   ctrl epoch 10 loss 0.185248
#   Early stopping control en época 13
#   val epoch 10 loss 1.058136
#   val epoch 20 loss 0.758181
#   val epoch 30 loss 0.582795
#
# === Paso 639/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.329202
#   val epoch 20 loss 0.870069
#   Early stopping valor en época 23
#
# === Paso 638/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 0.863968
#   val epoch 20 loss 0.619803
#   val epoch 30 loss 0.400714
#
# === Paso 637/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.150558
#   val epoch 20 loss 0.700017
#   val epoch 30 loss 0.767424
#
# === Paso 636/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.740947
#   val epoch 20 loss 0.688236
#   val epoch 30 loss 0.561083
#
# === Paso 635/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.732648
#   val epoch 20 loss 1.300133
#   val epoch 30 loss 0.833077
#
# === Paso 634/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 2.441400
#   val epoch 20 loss 1.821405
#   val epoch 30 loss 1.110349
#
# === Paso 633/1999 ===
#   Early stopping control en época 7
#   Early stopping valor en época 9
#
# === Paso 632/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.910783
#   Early stopping valor en época 16
#
# === Paso 631/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.356043
#   val epoch 20 loss 0.996052
#   Early stopping valor en época 23
#
# === Paso 630/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 0.726002
#   val epoch 20 loss 0.428404
#   val epoch 30 loss 0.408466
#
# === Paso 629/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.284094
#   val epoch 20 loss 0.959936
#   Early stopping valor en época 26
#
# === Paso 628/1999 ===
#   Early stopping control en época 6
#   Early stopping valor en época 9
#
# === Paso 627/1999 ===
#   ctrl epoch 10 loss 0.028774
#   Early stopping control en época 14
#   val epoch 10 loss 2.529897
#   val epoch 20 loss 2.677151
#   Early stopping valor en época 22
#
# === Paso 626/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.425375
#   val epoch 20 loss 0.975161
#   Early stopping valor en época 27
#
# === Paso 625/1999 ===
#   ctrl epoch 10 loss 0.104025
#   Early stopping control en época 11
#   val epoch 10 loss 1.890851
#   val epoch 20 loss 1.266758
#   val epoch 30 loss 1.181695
#
# === Paso 624/1999 ===
#   ctrl epoch 10 loss 0.120957
#   Early stopping control en época 11
#   val epoch 10 loss 1.085977
#   val epoch 20 loss 0.812672
#   val epoch 30 loss 0.589877
#
# === Paso 623/1999 ===
#   ctrl epoch 10 loss 0.023724
#   Early stopping control en época 13
#   Early stopping valor en época 6
#
# === Paso 622/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.257371
#   val epoch 20 loss 0.681831
#   Early stopping valor en época 22
#
# === Paso 621/1999 ===
#   Early stopping control en época 7
#   Early stopping valor en época 8
#
# === Paso 620/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.017123
#   Early stopping valor en época 17
#
# === Paso 619/1999 ===
#   ctrl epoch 10 loss 0.008642
#   Early stopping control en época 15
#   val epoch 10 loss 1.261379
#   val epoch 20 loss 0.888234
#   val epoch 30 loss 0.546446
#
# === Paso 618/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.232859
#   val epoch 20 loss 0.868147
#   Early stopping valor en época 21
#
# === Paso 617/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.577571
#   val epoch 20 loss 1.150123
#   val epoch 30 loss 0.819071
#
# === Paso 616/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.783225
#   val epoch 20 loss 1.424958
#   val epoch 30 loss 0.815826
#
# === Paso 615/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.543697
#   val epoch 20 loss 0.432454
#   val epoch 30 loss 0.346782
#
# === Paso 614/1999 ===
#   ctrl epoch 10 loss 0.146671
#   Early stopping control en época 12
#   val epoch 10 loss 1.527836
#   val epoch 20 loss 1.095725
#   val epoch 30 loss 0.725466
#
# === Paso 613/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.321532
#   val epoch 20 loss 0.775368
#   Early stopping valor en época 25
#
# === Paso 612/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.003529
#   val epoch 20 loss 0.867323
#   val epoch 30 loss 0.499030
#
# === Paso 611/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.445046
#   val epoch 20 loss 0.848862
#   val epoch 30 loss 0.683042
#
# === Paso 610/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.047031
#   val epoch 20 loss 0.760793
#   val epoch 30 loss 0.516112
#
# === Paso 609/1999 ===
#   ctrl epoch 10 loss 0.082064
#   Early stopping control en época 13
#   val epoch 10 loss 2.349329
#   Early stopping valor en época 18
#
# === Paso 608/1999 ===
#   ctrl epoch 10 loss 0.081657
#   Early stopping control en época 16
#   val epoch 10 loss 1.488863
#   Early stopping valor en época 16
#
# === Paso 607/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.775023
#   Early stopping valor en época 20
#
# === Paso 606/1999 ===
#   ctrl epoch 10 loss 0.089458
#   Early stopping control en época 11
#   val epoch 10 loss 4.725837
#   Early stopping valor en época 16
#
# === Paso 605/1999 ===
#   ctrl epoch 10 loss 0.131393
#   Early stopping control en época 11
#   val epoch 10 loss 1.983223
#   val epoch 20 loss 1.794500
#   val epoch 30 loss 1.208512
#
# === Paso 604/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 0.716755
#   val epoch 20 loss 0.523672
#   val epoch 30 loss 0.311579
#
# === Paso 603/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.498163
#   val epoch 20 loss 0.924250
#   val epoch 30 loss 0.628162
#
# === Paso 602/1999 ===
#   ctrl epoch 10 loss 0.070863
#   Early stopping control en época 16
#   val epoch 10 loss 1.151969
#   val epoch 20 loss 1.023218
#   val epoch 30 loss 0.840773
#
# === Paso 601/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 2.772252
#   val epoch 20 loss 1.731349
#   val epoch 30 loss 1.507220
#
# === Paso 600/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.052180
#   val epoch 20 loss 0.713324
#   val epoch 30 loss 0.530261
#
# === Paso 599/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.788175
#   val epoch 20 loss 1.094456
#   val epoch 30 loss 0.789320
#
# === Paso 598/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.648851
#   val epoch 20 loss 1.050199
#   val epoch 30 loss 0.706561
#
# === Paso 597/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.836933
#   Early stopping valor en época 15
#
# === Paso 596/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 2.141782
#   val epoch 20 loss 1.329681
#   Early stopping valor en época 28
#
# === Paso 595/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.223327
#   Early stopping valor en época 14
#
# === Paso 594/1999 ===
#   ctrl epoch 10 loss 0.108038
#   Early stopping control en época 16
#   val epoch 10 loss 2.298674
#   Early stopping valor en época 13
#
# === Paso 593/1999 ===
#   ctrl epoch 10 loss 0.125734
#   Early stopping control en época 16
#   val epoch 10 loss 1.212912
#   val epoch 20 loss 0.872003
#   val epoch 30 loss 0.455299
#
# === Paso 592/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 0.926126
#   val epoch 20 loss 0.652704
#   Early stopping valor en época 23
#
# === Paso 591/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.747099
#   val epoch 20 loss 1.267311
#   val epoch 30 loss 1.077929
#
# === Paso 590/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.036645
#   val epoch 20 loss 0.845357
#   val epoch 30 loss 0.576054
#
# === Paso 589/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.873655
#   val epoch 20 loss 0.508166
#   Early stopping valor en época 30
#
# === Paso 588/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 2.386792
#   val epoch 20 loss 1.441669
#   val epoch 30 loss 1.132887
#
# === Paso 587/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 3.401125
#   val epoch 20 loss 2.324790
#   val epoch 30 loss 1.825982
#
# === Paso 586/1999 ===
#   Early stopping control en época 6
#   Early stopping valor en época 9
#
# === Paso 585/1999 ===
#   ctrl epoch 10 loss 0.049697
#   Early stopping control en época 11
#   val epoch 10 loss 2.170560
#   Early stopping valor en época 11
#
# === Paso 584/1999 ===
#   ctrl epoch 10 loss 0.044333
#   Early stopping control en época 11
#   Early stopping valor en época 6
#
# === Paso 583/1999 ===
#   ctrl epoch 10 loss 0.049867
#   Early stopping control en época 11
#   val epoch 10 loss 1.168138
#   val epoch 20 loss 0.697006
#   Early stopping valor en época 22
#
# === Paso 582/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.868339
#   val epoch 20 loss 0.615741
#   val epoch 30 loss 0.445157
#
# === Paso 581/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 0.729198
#   Early stopping valor en época 13
#
# === Paso 580/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 0.662302
#   val epoch 20 loss 0.529638
#   val epoch 30 loss 0.305770
#
# === Paso 579/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.039694
#   val epoch 20 loss 0.721829
#   Early stopping valor en época 22
#
# === Paso 578/1999 ===
#   Early stopping control en época 6
#   Early stopping valor en época 7
#
# === Paso 577/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.400049
#   val epoch 20 loss 0.923193
#   Early stopping valor en época 21
#
# === Paso 576/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.108428
#   val epoch 20 loss 0.974025
#   val epoch 30 loss 0.533216
#
# === Paso 575/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.814847
#   val epoch 20 loss 0.526843
#   Early stopping valor en época 21
#
# === Paso 574/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.638379
#   val epoch 20 loss 1.160804
#   val epoch 30 loss 0.752031
#
# === Paso 573/1999 ===
#   ctrl epoch 10 loss 0.097344
#   Early stopping control en época 12
#   val epoch 10 loss 2.655745
#   Early stopping valor en época 17
#
# === Paso 572/1999 ===
#   ctrl epoch 10 loss 0.098381
#   Early stopping control en época 11
#   val epoch 10 loss 1.374105
#   val epoch 20 loss 0.839419
#   val epoch 30 loss 0.726926
#
# === Paso 571/1999 ===
#   ctrl epoch 10 loss 0.021707
#   Early stopping control en época 11
#   val epoch 10 loss 2.460487
#   val epoch 20 loss 1.794089
#   Early stopping valor en época 21
#
# === Paso 570/1999 ===
#   ctrl epoch 10 loss 0.040685
#   Early stopping control en época 11
#   val epoch 10 loss 2.323313
#   val epoch 20 loss 1.464762
#   Early stopping valor en época 23
#
# === Paso 569/1999 ===
#   ctrl epoch 10 loss 0.093902
#   Early stopping control en época 12
#   val epoch 10 loss 0.936029
#   val epoch 20 loss 0.730386
#   Early stopping valor en época 21
#
# === Paso 568/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.908243
#   Early stopping valor en época 11
#
# === Paso 567/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.437954
#   Early stopping valor en época 11
#
# === Paso 566/1999 ===
#   ctrl epoch 10 loss 0.002267
#   Early stopping control en época 12
#   val epoch 10 loss 2.581776
#   val epoch 20 loss 1.940439
#   Early stopping valor en época 21
#
# === Paso 565/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 2.251643
#   Early stopping valor en época 14
#
# === Paso 564/1999 ===
#   ctrl epoch 10 loss 0.069508
#   Early stopping control en época 12
#   val epoch 10 loss 1.429584
#   val epoch 20 loss 0.767063
#   val epoch 30 loss 0.588447
#
# === Paso 563/1999 ===
#   ctrl epoch 10 loss 0.159044
#   Early stopping control en época 13
#   val epoch 10 loss 0.989607
#   Early stopping valor en época 14
#
# === Paso 562/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.760629
#   Early stopping valor en época 11
#
# === Paso 561/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.488496
#   val epoch 20 loss 1.091839
#   Early stopping valor en época 22
#
# === Paso 560/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 2.066802
#   val epoch 20 loss 1.205765
#   val epoch 30 loss 0.893257
#
# === Paso 559/1999 ===
#   ctrl epoch 10 loss 0.035090
#   Early stopping control en época 12
#   val epoch 10 loss 2.104567
#   val epoch 20 loss 1.478412
#   val epoch 30 loss 1.098413
#
# === Paso 558/1999 ===
#   ctrl epoch 10 loss 0.157892
#   Early stopping control en época 16
#   val epoch 10 loss 0.912809
#   val epoch 20 loss 0.561450
#   val epoch 30 loss 0.478979
#
# === Paso 557/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.336348
#   Early stopping valor en época 19
#
# === Paso 556/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.323283
#   Early stopping valor en época 20
#
# === Paso 555/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.039684
#   Early stopping valor en época 19
#
# === Paso 554/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.099469
#   Early stopping valor en época 16
#
# === Paso 553/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.608038
#   val epoch 20 loss 1.213185
#   val epoch 30 loss 0.763184
#
# === Paso 552/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.868901
#   val epoch 20 loss 1.015769
#   Early stopping valor en época 25
#
# === Paso 551/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 0.551230
#   Early stopping valor en época 19
#
# === Paso 550/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 0.729896
#   val epoch 20 loss 0.578684
#   Early stopping valor en época 30
#
# === Paso 549/1999 ===
#   Early stopping control en época 6
#   Early stopping valor en época 9
#
# === Paso 548/1999 ===
#   ctrl epoch 10 loss 0.156380
#   Early stopping control en época 13
#   val epoch 10 loss 0.896843
#   val epoch 20 loss 0.740550
#   val epoch 30 loss 0.422143
#
# === Paso 547/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.093253
#   val epoch 20 loss 0.883421
#   val epoch 30 loss 0.682785
#
# === Paso 546/1999 ===
#   ctrl epoch 10 loss 0.147923
#   Early stopping control en época 12
#   val epoch 10 loss 1.701648
#   val epoch 20 loss 1.309002
#   Early stopping valor en época 26
#
# === Paso 545/1999 ===
#   ctrl epoch 10 loss 0.130356
#   Early stopping control en época 13
#   Early stopping valor en época 9
#
# === Paso 544/1999 ===
#   Early stopping control en época 10
#   Early stopping valor en época 9
#
# === Paso 543/1999 ===
#   ctrl epoch 10 loss 0.243495
#   Early stopping control en época 11
#   val epoch 10 loss 0.772809
#   val epoch 20 loss 0.542270
#   val epoch 30 loss 0.350474
#
# === Paso 542/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 2.492820
#   val epoch 20 loss 1.612281
#   Early stopping valor en época 22
#
# === Paso 541/1999 ===
#   ctrl epoch 10 loss 0.088065
#   Early stopping control en época 15
#   val epoch 10 loss 1.414339
#   val epoch 20 loss 0.938544
#   val epoch 30 loss 0.628639
#
# === Paso 540/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.196892
#   Early stopping valor en época 16
#
# === Paso 539/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 2.615691
#   val epoch 20 loss 1.791464
#   val epoch 30 loss 1.082835
#
# === Paso 538/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.514136
#   Early stopping valor en época 12
#
# === Paso 537/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.828004
#   Early stopping valor en época 12
#
# === Paso 536/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.220543
#   val epoch 20 loss 0.782936
#   Early stopping valor en época 22
#
# === Paso 535/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.089351
#   val epoch 20 loss 0.597259
#   Early stopping valor en época 30
#
# === Paso 534/1999 ===
# ...
#   val epoch 20 loss 0.756655
#   Early stopping valor en época 21
#
# === Paso 110/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 0.838492
#   val epoch 20 loss 0.735326
#   val epoch 30 loss 0.517827
#
# === Paso 109/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.061184
#   Early stopping valor en época 17
#
# === Paso 108/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.973161
#   val epoch 20 loss 0.730869
#   Early stopping valor en época 26
#
# === Paso 107/1999 ===
#   ctrl epoch 10 loss 0.054936
#   Early stopping control en época 11
#   val epoch 10 loss 0.992826
#   val epoch 20 loss 0.612546
#   Early stopping valor en época 23
#
# === Paso 106/1999 ===
#   Early stopping control en época 6
#   Early stopping valor en época 10
#
# === Paso 105/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.109608
#   val epoch 20 loss 0.870833
#   val epoch 30 loss 0.660772
#
# === Paso 104/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.627152
#   Early stopping valor en época 16
#
# === Paso 103/1999 ===
#   ctrl epoch 10 loss 0.085202
#   Early stopping control en época 11
#   val epoch 10 loss 1.466390
#   val epoch 20 loss 1.224581
#   Early stopping valor en época 26
#
# === Paso 102/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 0.719856
#   val epoch 20 loss 0.520684
#   val epoch 30 loss 0.327822
#
# === Paso 101/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 0.882867
#   val epoch 20 loss 0.594315
#   val epoch 30 loss 0.661226
#
# === Paso 100/1999 ===
#   ctrl epoch 10 loss 0.018494
#   Early stopping control en época 15
#   val epoch 10 loss 0.501898
#   val epoch 20 loss 0.412823
#   val epoch 30 loss 0.269374
#
# === Paso 99/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 2.551156
#   val epoch 20 loss 1.539109
#   val epoch 30 loss 1.046051
#
# === Paso 98/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.823570
#   Early stopping valor en época 17
#
# === Paso 97/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.176906
#   val epoch 20 loss 0.676859
#   Early stopping valor en época 24
#
# === Paso 96/1999 ===
#   Early stopping control en época 6
#   Early stopping valor en época 8
#
# === Paso 95/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 0.814870
#   Early stopping valor en época 11
#
# === Paso 94/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.087103
#   val epoch 20 loss 0.842442
#   Early stopping valor en época 30
#
# === Paso 93/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 0.913801
#   val epoch 20 loss 0.540668
#   val epoch 30 loss 0.293491
#
# === Paso 92/1999 ===
#   ctrl epoch 10 loss 0.085284
#   Early stopping control en época 16
#   val epoch 10 loss 1.655225
#   val epoch 20 loss 0.885488
#   val epoch 30 loss 0.661933
#
# === Paso 91/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.462853
#   val epoch 20 loss 1.144332
#   val epoch 30 loss 0.804768
#
# === Paso 90/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.737245
#   val epoch 20 loss 1.217607
#   val epoch 30 loss 0.787085
#
# === Paso 89/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.452428
#   val epoch 20 loss 0.317261
#   val epoch 30 loss 0.189371
#
# === Paso 88/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.137944
#   val epoch 20 loss 0.438534
#   Early stopping valor en época 25
#
# === Paso 87/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.779256
#   val epoch 20 loss 0.906817
#   val epoch 30 loss 0.735089
#
# === Paso 86/1999 ===
#   ctrl epoch 10 loss 0.123546
#   Early stopping control en época 14
#   val epoch 10 loss 0.911902
#   val epoch 20 loss 0.759874
#   Early stopping valor en época 22
#
# === Paso 85/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.050424
#   Early stopping valor en época 13
#
# === Paso 84/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 2.557148
#   val epoch 20 loss 1.334589
#   Early stopping valor en época 25
#
# === Paso 83/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.000746
#   Early stopping valor en época 13
#
# === Paso 82/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 0.842292
#   val epoch 20 loss 0.594122
#   val epoch 30 loss 0.289780
#
# === Paso 81/1999 ===
#   Early stopping control en época 7
#   Early stopping valor en época 9
#
# === Paso 80/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 0.932586
#   Early stopping valor en época 11
#
# === Paso 79/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 3.512083
#   Early stopping valor en época 20
#
# === Paso 78/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 0.759552
#   Early stopping valor en época 17
#
# === Paso 77/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.238815
#   val epoch 20 loss 0.839450
#   val epoch 30 loss 0.599909
#
# === Paso 76/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 2.084247
#   val epoch 20 loss 1.339392
#   val epoch 30 loss 0.905946
#
# === Paso 75/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 2.149084
#   val epoch 20 loss 1.488438
#   Early stopping valor en época 23
#
# === Paso 74/1999 ===
#   ctrl epoch 10 loss 0.147850
#   Early stopping control en época 14
#   val epoch 10 loss 1.888673
#   val epoch 20 loss 1.322373
#   val epoch 30 loss 0.936065
#
# === Paso 73/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 0.851654
#   val epoch 20 loss 0.622209
#   Early stopping valor en época 27
#
# === Paso 72/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.255481
#   val epoch 20 loss 0.883005
#   val epoch 30 loss 0.578474
#
# === Paso 71/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.336799
#   val epoch 20 loss 1.094015
#   val epoch 30 loss 0.596140
#
# === Paso 70/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 0.998830
#   val epoch 20 loss 0.794346
#   Early stopping valor en época 25
#
# === Paso 69/1999 ===
#   Early stopping control en época 7
#   Early stopping valor en época 8
#
# === Paso 68/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.411418
#   Early stopping valor en época 13
#
# === Paso 67/1999 ===
#   ctrl epoch 10 loss 0.091965
#   Early stopping control en época 16
#   val epoch 10 loss 1.492944
#   val epoch 20 loss 1.046199
#   val epoch 30 loss 0.613272
#
# === Paso 66/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.425469
#   val epoch 20 loss 0.894596
#   Early stopping valor en época 30
#
# === Paso 65/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 2.054127
#   val epoch 20 loss 1.662808
#   val epoch 30 loss 1.101456
#
# === Paso 64/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 0.609563
#   val epoch 20 loss 0.561407
#   val epoch 30 loss 0.349252
#
# === Paso 63/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.014470
#   Early stopping valor en época 19
#
# === Paso 62/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.328835
#   val epoch 20 loss 0.914510
#   Early stopping valor en época 21
#
# === Paso 61/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.017245
#   Early stopping valor en época 20
#
# === Paso 60/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 2.197761
#   Early stopping valor en época 13
#
# === Paso 59/1999 ===
#   Early stopping control en época 9
#   Early stopping valor en época 8
#
# === Paso 58/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.559835
#   val epoch 20 loss 0.743674
#   Early stopping valor en época 25
#
# === Paso 57/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.318439
#   val epoch 20 loss 0.822355
#   val epoch 30 loss 0.539696
#
# === Paso 56/1999 ===
#   ctrl epoch 10 loss 0.068884
#   Early stopping control en época 12
#   val epoch 10 loss 2.513345
#   Early stopping valor en época 17
#
# === Paso 55/1999 ===
#   Early stopping control en época 6
#   Early stopping valor en época 7
#
# === Paso 54/1999 ===
#   ctrl epoch 10 loss 0.029813
#   Early stopping control en época 12
#   val epoch 10 loss 0.660252
#   val epoch 20 loss 0.450908
#   val epoch 30 loss 0.495734
#
# === Paso 53/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 2.142345
#   Early stopping valor en época 14
#
# === Paso 52/1999 ===
#   ctrl epoch 10 loss 0.152920
#   Early stopping control en época 14
#   val epoch 10 loss 1.328232
#   val epoch 20 loss 0.881582
#   val epoch 30 loss 0.634294
#
# === Paso 51/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.246249
#   val epoch 20 loss 0.997386
#   val epoch 30 loss 0.674210
#
# === Paso 50/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.295346
#   Early stopping valor en época 16
#
# === Paso 49/1999 ===
#   ctrl epoch 10 loss 0.047200
#   Early stopping control en época 15
#   val epoch 10 loss 1.455537
#   val epoch 20 loss 0.660382
#   val epoch 30 loss 0.627653
#
# === Paso 48/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.565967
#   val epoch 20 loss 1.285418
#   val epoch 30 loss 0.777581
#
# === Paso 47/1999 ===
#   ctrl epoch 10 loss 0.069149
#   Early stopping control en época 11
#   val epoch 10 loss 1.123209
#   Early stopping valor en época 20
#
# === Paso 46/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.739686
#   val epoch 20 loss 0.899970
#   val epoch 30 loss 0.693785
#
# === Paso 45/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 0.880996
#   val epoch 20 loss 0.770455
#   val epoch 30 loss 0.340222
#
# === Paso 44/1999 ===
#   ctrl epoch 10 loss 0.189376
#   Early stopping control en época 13
#   val epoch 10 loss 0.920006
#   Early stopping valor en época 11
#
# === Paso 43/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.710056
#   val epoch 20 loss 1.089652
#   val epoch 30 loss 0.673095
#
# === Paso 42/1999 ===
#   ctrl epoch 10 loss 0.016938
#   Early stopping control en época 12
#   val epoch 10 loss 1.794311
#   val epoch 20 loss 1.249075
#   val epoch 30 loss 0.878997
#
# === Paso 41/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.866908
#   val epoch 20 loss 1.198185
#   Early stopping valor en época 22
#
# === Paso 40/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.363546
#   Early stopping valor en época 18
#
# === Paso 39/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.086708
#   val epoch 20 loss 1.215363
#   Early stopping valor en época 22
#
# === Paso 38/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 2.056427
#   Early stopping valor en época 12
#
# === Paso 37/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 4.666787
#   val epoch 20 loss 3.163530
#   val epoch 30 loss 1.618996
#
# === Paso 36/1999 ===
#   ctrl epoch 10 loss 0.111428
#   Early stopping control en época 11
#   val epoch 10 loss 3.221647
#   Early stopping valor en época 19
#
# === Paso 35/1999 ===
#   ctrl epoch 10 loss 0.146084
#   Early stopping control en época 12
#   val epoch 10 loss 3.406559
#   val epoch 20 loss 2.709133
#   Early stopping valor en época 24
#
# === Paso 34/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.041540
#   val epoch 20 loss 0.632107
#   Early stopping valor en época 28
#
# === Paso 33/1999 ===
#   ctrl epoch 10 loss 0.045950
#   Early stopping control en época 15
#   val epoch 10 loss 1.196611
#   val epoch 20 loss 0.873948
#   Early stopping valor en época 30
#
# === Paso 32/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.473767
#   Early stopping valor en época 15
#
# === Paso 31/1999 ===
#   ctrl epoch 10 loss 0.055222
#   Early stopping control en época 14
#   val epoch 10 loss 0.832114
#   Early stopping valor en época 20
#
# === Paso 30/1999 ===
#   ctrl epoch 10 loss 0.053442
#   Early stopping control en época 16
#   val epoch 10 loss 2.437193
#   Early stopping valor en época 14
#
# === Paso 29/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 0.699586
#   Early stopping valor en época 12
#
# === Paso 28/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 0.770941
#   Early stopping valor en época 20
#
# === Paso 27/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 0.737057
#   Early stopping valor en época 20
#
# === Paso 26/1999 ===
#   ctrl epoch 10 loss 0.108655
#   Early stopping control en época 13
#   val epoch 10 loss 1.332022
#   val epoch 20 loss 0.895169
#   val epoch 30 loss 0.701379
#
# === Paso 25/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 0.805775
#   val epoch 20 loss 0.783793
#   Early stopping valor en época 23
#
# === Paso 24/1999 ===
#   ctrl epoch 10 loss 0.028514
#   Early stopping control en época 12
#   Early stopping valor en época 6
#
# === Paso 23/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.043153
#   Early stopping valor en época 18
#
# === Paso 22/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 1.317668
#   Early stopping valor en época 14
#
# === Paso 21/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 1.297710
#   val epoch 20 loss 0.754036
#   val epoch 30 loss 0.800614
#
# === Paso 20/1999 ===
#   Early stopping control en época 6
#   Early stopping valor en época 7
#
# === Paso 19/1999 ===
#   Early stopping control en época 10
#   val epoch 10 loss 0.908159
#   val epoch 20 loss 0.520638
#   Early stopping valor en época 29
#
# === Paso 18/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 0.830582
#   val epoch 20 loss 0.453651
#   Early stopping valor en época 25
#
# === Paso 17/1999 ===
#   ctrl epoch 10 loss 0.183078
#   Early stopping control en época 11
#   val epoch 10 loss 1.421643
#   val epoch 20 loss 0.898825
#   Early stopping valor en época 26
#
# === Paso 16/1999 ===
#   Early stopping control en época 9
#   val epoch 10 loss 1.792700
#   val epoch 20 loss 1.401166
#   val epoch 30 loss 1.014290
#
# === Paso 15/1999 ===
#   ctrl epoch 10 loss 0.198841
#   Early stopping control en época 11
#   val epoch 10 loss 1.652304
#   val epoch 20 loss 1.372072
#   val epoch 30 loss 0.876631
#
# === Paso 14/1999 ===
#   ctrl epoch 10 loss 0.147082
#   Early stopping control en época 14
#   val epoch 10 loss 1.739892
#   Early stopping valor en época 13
#
# === Paso 13/1999 ===
#   ctrl epoch 10 loss 0.050505
#   Early stopping control en época 15
#   val epoch 10 loss 0.796396
#   Early stopping valor en época 13
#
# === Paso 12/1999 ===
#   ctrl epoch 10 loss 0.007542
#   Early stopping control en época 12
#   val epoch 10 loss 1.872753
#   val epoch 20 loss 0.995003
#   val epoch 30 loss 0.693902
#
# === Paso 11/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.383317
#   val epoch 20 loss 0.937588
#   val epoch 30 loss 0.484041
#
# === Paso 10/1999 ===
#   ctrl epoch 10 loss 0.083969
#   Early stopping control en época 13
#   Early stopping valor en época 7
#
# === Paso 9/1999 ===
#   Early stopping control en época 7
#   val epoch 10 loss 1.013717
#   val epoch 20 loss 0.780317
#   val epoch 30 loss 0.555400
#
# === Paso 8/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.570497
#   val epoch 20 loss 0.410038
#   Early stopping valor en época 26
#
# === Paso 7/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.543148
#   val epoch 20 loss 0.580816
#   Early stopping valor en época 22
#
# === Paso 6/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.504380
#   val epoch 20 loss 1.091854
#   val epoch 30 loss 0.790125
#
# === Paso 5/1999 ===
#   ctrl epoch 10 loss 0.100994
#   Early stopping control en época 12
#   val epoch 10 loss 2.007592
#   val epoch 20 loss 1.003655
#   Early stopping valor en época 25
#
# === Paso 4/1999 ===
#   ctrl epoch 10 loss 0.021299
#   Early stopping control en época 12
#   val epoch 10 loss 1.564264
#   Early stopping valor en época 15
#
# === Paso 3/1999 ===
#   Early stopping control en época 8
#   val epoch 10 loss 1.777957
#   Early stopping valor en época 15
#
# === Paso 2/1999 ===
#   Early stopping control en época 6
#   val epoch 10 loss 0.860764
#   val epoch 20 loss 0.777978
#   Early stopping valor en época 24
#
# === Paso 1/1999 ===
#   ctrl epoch 10 loss 0.052098
#   Early stopping control en época 15
#   val epoch 10 loss 1.866700
#   val epoch 20 loss 1.240713
#   val epoch 30 loss 0.680789
#
# === Paso 0/1999 ===
#   Early stopping control en época 10
#   Early stopping valor en época 7

# %%
# ============================================
# PLOTEO COHERENTE CON LA VERSIÓN ESTABILIZADA
# ============================================
import numpy as np
import matplotlib.pyplot as plt
# CAMBIO 1: Calcular y_inicial para w_ref = [5.0, 5.0] (no [15.0, 5.0])
A_np = np.array([[1., 0., 0.5], [0., 1., 0.5]])
w_ref_0_correcto = np.array([5.0, 5.0])  # ← CAMBIO: Ahora es [5.0, 5.0]
y_inicial_correcto = np.linalg.pinv(A_np) @ w_ref_0_correcto
# Si aún no tienes la trayectoria, genera una:
# x0 de ejemplo (cerca del punto de operación)
x0 = np.array([880., 880., 880.,
               y_inicial_correcto[0],
               y_inicial_correcto[1],
               y_inicial_correcto[2],
               0.0], dtype=np.float32)


# Usa tus arrays resultantes:
traj = traj_opt          # shape [N+1, 7]
ctrls = controls_opt     # shape [N, 3]

# REEMPLAZA TODO EL CÓDIGO DE ANÁLISIS CON ESTO:

import numpy as np
import matplotlib.pyplot as plt

# Parámetros consistentes con el entrenamiento
T = 0.8
N = ctrls.shape[0]
M = traj.shape[0]
dt = T / N
times = np.linspace(0, T, M)
times_ctrl = times[:-1]

# Extraer estados
x = traj[:, :3]
y = traj[:, 3:6]
z = traj[:, 6]
u = ctrls

# Matrices del sistema
A_mat = np.array([[1., 0., 0.5],
                  [0., 1., 0.5]])
A_pinv = np.linalg.pinv(A_mat)
K_mat = np.array([[ 2/3, -1/3, -1/3],
                  [-1/3,  2/3, -1/3],
                  [-1/3, -1/3,  2/3]])

# Referencias (CONSISTENTES CON EL ENTRENAMIENTO)
x_ref = np.array([880., 880., 880.])

# Parámetros de normalización
E_w_N_sq = 250.0  # Aproximado
E_x_N_sq = 500000.0
E_z_N_sq = 150.0
E_u_N_sq = 1000000.0

# Arrays para almacenar resultados
e_x_arr = np.zeros((N, 3))
e_w_arr = np.zeros((N, 2))
w_ref_arr = np.zeros((N, 2))
w_actual_arr = np.zeros((N, 2))
Jw = np.zeros(N)
Jx = np.zeros(N)
Jz = np.zeros(N)
Ju = np.zeros(N)

# Calcular errores para cada paso temporal
for i in range(N):
    t = times_ctrl[i]
    xi = x[i]
    yi = y[i]
    ui = u[i]

    # IMPORTANTE: Usar la MISMA frecuencia que en el entrenamiento (10π, no 40π)
    w_ref = np.array([5.0, 5.0 * np.cos(5.0 * np.pi * t)])  # ¡CORREGIDO!
    w_ref_arr[i] = w_ref

    # Salida actual
    w_actual = yi.dot(A_mat.T)
    w_actual_arr[i] = w_actual

    # Error de seguimiento
    ew = w_actual - w_ref
    e_w_arr[i] = ew

    # Error de estado
    ex = xi - x_ref
    e_x_arr[i] = ex

    # Error de espacio nulo
    zmat = np.eye(3) - A_pinv.dot(A_mat)
    ez = yi.dot(zmat.T)

    # Error de control
    d_ref = np.array([500.0, 300.0 * np.cos(5.0 * np.pi * t)])  # ¡CORREGIDO!
    ATd = d_ref.dot(A_mat)
    Kxu = (xi * ui).dot(K_mat.T)
    eu = ATd - Kxu

    # Funcionales normalizados
    Jw[i] = np.sum(ew**2) / E_w_N_sq
    Jx[i] = np.sum(ex**2) / E_x_N_sq
    Jz[i] = np.sum(ez**2) / E_z_N_sq
    Ju[i] = np.sum(eu) / E_u_N_sq

# ============================================================================
# VISUALIZACIÓN MEJORADA
# ============================================================================

# Crear figura con subplots organizados
fig = plt.figure(figsize=(16, 12))

# 1. Error de seguimiento Ay - w_ref
ax1 = plt.subplot(3, 3, 1)
ax1.plot(times_ctrl, e_w_arr[:,0], 'b-', label='Error comp. 1', linewidth=2)
ax1.plot(times_ctrl, e_w_arr[:,1], 'r-', label='Error comp. 2', linewidth=2)
ax1.set_xlabel('Tiempo (s)')
ax1.set_ylabel('Error')
ax1.set_title('Error de Seguimiento (Ay - w_ref)')
ax1.legend()
ax1.grid(True, alpha=0.3)

# 2. Comparación w_ref vs Ay (componente 1)
ax2 = plt.subplot(3, 3, 2)
ax2.plot(times_ctrl, w_ref_arr[:,0], 'b--', label='w_ref_1', linewidth=2)
ax2.plot(times_ctrl, w_actual_arr[:,0], 'b-', label='Ay_1', linewidth=2)
ax2.set_xlabel('Tiempo (s)')
ax2.set_ylabel('Valor')
ax2.set_title('Seguimiento Componente 1')
ax2.legend()
ax2.grid(True, alpha=0.3)

# 3. Comparación w_ref vs Ay (componente 2)
ax3 = plt.subplot(3, 3, 3)
ax3.plot(times_ctrl, w_ref_arr[:,1], 'r--', label='w_ref_2', linewidth=2)
ax3.plot(times_ctrl, w_actual_arr[:,1], 'r-', label='Ay_2', linewidth=2)
ax3.set_xlabel('Tiempo (s)')
ax3.set_ylabel('Valor')
ax3.set_title('Seguimiento Componente 2 (Sinusoidal)')
ax3.legend()
ax3.grid(True, alpha=0.3)

# 4. Estados x
ax4 = plt.subplot(3, 3, 4)
for i in range(3):
    ax4.plot(times, x[:,i], label=f'x_{i+1}')
ax4.axhline(y=880, color='k', linestyle='--', alpha=0.5)
ax4.set_xlabel('Tiempo (s)')
ax4.set_ylabel('x')
ax4.set_title('Estados x (Voltajes)')
ax4.legend()
ax4.grid(True, alpha=0.3)

# 5. Estados y
ax5 = plt.subplot(3, 3, 5)
for i in range(3):
    ax5.plot(times, y[:,i], label=f'y_{i+1}')
ax5.set_xlabel('Tiempo (s)')
ax5.set_ylabel('y')
ax5.set_title('Estados y (Corrientes)')
ax5.legend()
ax5.grid(True, alpha=0.3)

# 6. Controles
ax6 = plt.subplot(3, 3, 6)
for i in range(3):
    ax6.plot(times_ctrl, u[:,i], label=f'u_{i+1}')
ax6.axhline(y=1, color='r', linestyle='--', alpha=0.5)
ax6.axhline(y=-1, color='r', linestyle='--', alpha=0.5)
ax6.set_xlabel('Tiempo (s)')
ax6.set_ylabel('u')
ax6.set_title('Señales de Control')
ax6.legend()
ax6.grid(True, alpha=0.3)

# 7. Funcionales normalizados
ax7 = plt.subplot(3, 3, 7)
ax7.plot(times_ctrl, Jw, label='J_w (seguimiento)', linewidth=2)
ax7.plot(times_ctrl, Jx, label='J_x (estado)', linewidth=2)
ax7.plot(times_ctrl, Jz, label='J_z (nulo)', linewidth=2)
ax7.plot(times_ctrl, Ju, label='J_u (control)', linewidth=2)
ax7.set_xlabel('Tiempo (s)')
ax7.set_ylabel('Costo')
ax7.set_title('Funcionales Normalizados')
ax7.legend()
ax7.grid(True, alpha=0.3)

# 8. Costo acumulado
ax8 = plt.subplot(3, 3, 8)
ax8.plot(times, z, 'g-', linewidth=2)
ax8.set_xlabel('Tiempo (s)')
ax8.set_ylabel('Costo acumulado')
ax8.set_title(f'Costo Total (Final: {z[-1]:.3f})')
ax8.grid(True, alpha=0.3)

# 9. Métricas de error
ax9 = plt.subplot(3, 3, 9)
rms_w1 = np.sqrt(np.mean(e_w_arr[:,0]**2))
rms_w2 = np.sqrt(np.mean(e_w_arr[:,1]**2))
max_w1 = np.max(np.abs(e_w_arr[:,0]))
max_w2 = np.max(np.abs(e_w_arr[:,1]))

metrics_text = f"""MÉTRICAS DE DESEMPEÑO:
RMS Error comp. 1: {rms_w1:.3f}
RMS Error comp. 2: {rms_w2:.3f}
Max Error comp. 1: {max_w1:.3f}
Max Error comp. 2: {max_w2:.3f}
Costo final: {z[-1]:.3f}
Controles saturados: {100*np.mean(np.abs(u) > 0.95):.1f}%
"""
ax9.text(0.1, 0.5, metrics_text, transform=ax9.transAxes,
         fontsize=11, verticalalignment='center',
         bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
ax9.axis('off')

plt.tight_layout()
plt.show()

# ============================================================================
# ANÁLISIS DE DIAGNÓSTICO
# ============================================================================

print("=" * 60)
print("DIAGNÓSTICO DEL CONTROLADOR")
print("=" * 60)

# Analizar error inicial
print(f"\n1. ERROR INICIAL:")
print(f"   w_ref(0) = {w_ref_arr[0]}")
print(f"   Ay(0) = {w_actual_arr[0]}")
print(f"   Error(0) = {e_w_arr[0]}")

# Analizar convergencia
print(f"\n2. CONVERGENCIA:")
print(f"   Error RMS comp. 1: {rms_w1:.4f}")
print(f"   Error RMS comp. 2: {rms_w2:.4f}")

# Analizar frecuencia
from scipy import signal
fs = 1.0 / dt
freqs, psd = signal.welch(e_w_arr[:,1], fs=fs, nperseg=min(256, N//4))
peak_freq = freqs[np.argmax(psd)]
print(f"\n3. ANÁLISIS DE FRECUENCIA:")
print(f"   Frecuencia de muestreo: {fs:.1f} Hz")
print(f"   Frecuencia de referencia: 5.0 Hz")
print(f"   Frecuencia dominante del error: {peak_freq:.1f} Hz")

# Verificar si el problema es de fase o amplitud
if N > 100:
    # Tomar la parte estacionaria (últimos 50%)
    steady_idx = N // 2
    steady_w_ref = w_ref_arr[steady_idx:, 1]
    steady_w_actual = w_actual_arr[steady_idx:, 1]

    # Calcular correlación cruzada
    correlation = np.correlate(steady_w_actual - np.mean(steady_w_actual),
                              steady_w_ref - np.mean(steady_w_ref), 'same')
    lag = np.argmax(np.abs(correlation)) - len(correlation)//2
    phase_delay = lag * dt

    print(f"\n4. ANÁLISIS DE FASE:")
    print(f"   Retardo estimado: {phase_delay*1000:.1f} ms")
    print(f"   Desfase: {phase_delay * 5 * 360:.1f}°")

print("\n" + "=" * 60)
# Out:
# ============================================================
# DIAGNÓSTICO DEL CONTROLADOR
# ============================================================
#
# 1. ERROR INICIAL:
#    w_ref(0) = [5. 5.]
#    Ay(0) = [15.  5.]
#    Error(0) = [10.  0.]
#
# 2. CONVERGENCIA:
#    Error RMS comp. 1: 17.2874
#    Error RMS comp. 2: 11.9538
#
# 3. ANÁLISIS DE FRECUENCIA:
#    Frecuencia de muestreo: 2500.0 Hz
#    Frecuencia de referencia: 5.0 Hz
#    Frecuencia dominante del error: 9.8 Hz
#
# 4. ANÁLISIS DE FASE:
#    Retardo estimado: 0.0 ms
#    Desfase: 0.0°
#
# ============================================================
